# %% [markdown]
# # Review Classification using Active Learning
#
# **Author:** [Darshan Deshpande](https://twitter.com/getdarshan)<br>
# **Date created:** 2021/10/29<br>
# **Last modified:** 2024/05/08<br>
# **Description:** Demonstrating the advantages of active learning through review classification.

# %% [markdown]
# ## Introduction
#
# With the growth of data-centric Machine Learning, Active Learning has grown in popularity
# amongst businesses and researchers. Active Learning seeks to progressively
# train ML models so that the resultant model requires lesser amount of training data to
# achieve competitive scores.
#
# The structure of an Active Learning pipeline involves a classifier and an oracle. The
# oracle is an annotator that cleans, selects, labels the data, and feeds it to the model
# when required. The oracle is a trained individual or a group of individuals that
# ensure consistency in labeling of new data.
#
# The process starts with annotating a small subset of the full dataset and training an
# initial model. The best model checkpoint is saved and then tested on a balanced test
# set. The test set must be carefully sampled because the full training process will be
# dependent on it. Once we have the initial evaluation scores, the oracle is tasked with
# labeling more samples; the number of data points to be sampled is usually determined by
# the business requirements. After that, the newly sampled data is added to the training
# set, and the training procedure repeats. This cycle continues until either an
# acceptable score is reached or some other business metric is met.
#
# This tutorial provides a basic demonstration of how Active Learning works by
# demonstrating a ratio-based (least confidence) sampling strategy that results in lower
# overall false positive and negative rates when compared to a model trained on the entire
# dataset. This sampling falls under the domain of *uncertainty sampling*, in which new
# datasets are sampled based on the uncertainty that the model outputs for the
# corresponding label. In our example, we compare our model's false positive and false
# negative rates and annotate the new data based on their ratio.
#
# Some other sampling techniques include:
#
# 1. [Committee sampling](https://www.researchgate.net/publication/51909346_Committee-Based_Sample_Selection_for_Probabilistic_Classifiers):
# Using multiple models to vote for the best data points to be sampled
# 2. [Entropy reduction](https://www.researchgate.net/publication/51909346_Committee-Based_Sample_Selection_for_Probabilistic_Classifiers):
# Sampling according to an entropy threshold, selecting more of the samples that produce the highest entropy score.
# 3. [Minimum margin based sampling](https://arxiv.org/abs/1906.00025v1):
# Selects data points closest to the decision boundary

# %% [markdown]
# ## Importing required libraries

# %%
# !pip install --upgrade keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.3.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.9.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.11.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"  # @param ["tensorflow", "jax", "torch"]
import keras
from keras import ops
from keras import layers
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import re
import string

tfds.disable_progress_bar()

# %% [markdown]
# ## Loading and preprocessing the data
#
# We will be using the IMDB reviews dataset for our experiments. This dataset has 50,000
# reviews in total, including training and testing splits. We will merge these splits and
# sample our own, balanced training, validation and testing sets.

# %%
dataset = tfds.load(
    "imdb_reviews",
    split="train + test",
    as_supervised=True,
    batch_size=-1,
    shuffle_files=False,
)
reviews, labels = tfds.as_numpy(dataset)

print("Total examples:", reviews.shape[0])
# Out:
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# Total examples: 50000

# %% [markdown]
# Active learning starts with labeling a subset of data.
# For the ratio sampling technique that we will be using, we will need well-balanced training,
# validation and testing splits.

# %%
val_split = 2500
test_split = 2500
train_split = 7500

# Separating the negative and positive samples for manual stratification
x_positives, y_positives = reviews[labels == 1], labels[labels == 1]
x_negatives, y_negatives = reviews[labels == 0], labels[labels == 0]

# Creating training, validation and testing splits
x_val, y_val = (
    tf.concat((x_positives[:val_split], x_negatives[:val_split]), 0),
    tf.concat((y_positives[:val_split], y_negatives[:val_split]), 0),
)
x_test, y_test = (
    tf.concat(
        (
            x_positives[val_split : val_split + test_split],
            x_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split : val_split + test_split],
            y_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
)
x_train, y_train = (
    tf.concat(
        (
            x_positives[val_split + test_split : val_split + test_split + train_split],
            x_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split + test_split : val_split + test_split + train_split],
            y_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
)

# Remaining pool of samples are stored separately. These are only labeled as and when required
x_pool_positives, y_pool_positives = (
    x_positives[val_split + test_split + train_split :],
    y_positives[val_split + test_split + train_split :],
)
x_pool_negatives, y_pool_negatives = (
    x_negatives[val_split + test_split + train_split :],
    y_negatives[val_split + test_split + train_split :],
)

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

pool_negatives = tf.data.Dataset.from_tensor_slices(
    (x_pool_negatives, y_pool_negatives)
)
pool_positives = tf.data.Dataset.from_tensor_slices(
    (x_pool_positives, y_pool_positives)
)

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled negative pool: {len(pool_negatives)}")
print(f"Unlabeled positive pool: {len(pool_positives)}")
# Out:
# Initial training set size: 15000
# Validation set size: 5000
# Testing set size: 5000
# Unlabeled negative pool: 12500
# Unlabeled positive pool: 12500

# %% [markdown]
# ### Fitting the `TextVectorization` layer
#
# Since we are working with text data, we will need to encode the text strings as vectors which
# would then be passed through an `Embedding` layer. To make this tokenization process
# faster, we use the `map()` function with its parallelization functionality.

# %%
vectorizer = layers.TextVectorization(
    3000, standardize="lower_and_strip_punctuation", output_sequence_length=150
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(256)
)


def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label


train_dataset = train_dataset.map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
pool_negatives = pool_negatives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)
pool_positives = pool_positives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %% [markdown]
# ## Creating Helper Functions

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %% [markdown]
# ## Creating the Model
#
# We create a small bidirectional LSTM model. When using Active Learning, you should make sure
# that the model architecture is capable of overfitting to the initial data.
# Overfitting gives a strong hint that the model will have enough capacity for
# future, unseen data.

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(150,)),
            layers.Embedding(input_dim=3000, output_dim=128),
            layers.Bidirectional(layers.LSTM(32, return_sequences=True)),
            layers.GlobalMaxPool1D(),
            layers.Dense(20, activation="relu"),
            layers.Dropout(0.5),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model

# %% [markdown]
# ## Training on the entire dataset
#
# To show the effectiveness of Active Learning, we will first train the model on the entire
# dataset containing 40,000 labeled samples. This model will be used for comparison later.

# %%
def train_full_model(full_train_dataset, val_dataset, test_dataset):
    model = create_model()
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # We will save the best model at every epoch and load the best one for evaluation on the test set
    history = model.fit(
        full_train_dataset.batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=4, verbose=1),
            keras.callbacks.ModelCheckpoint(
                "FullModelCheckpoint.keras", verbose=1, save_best_only=True
            ),
        ],
    )

    # Plot history
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["binary_accuracy"],
        history.history["val_binary_accuracy"],
    )

    # Loading the best checkpoint
    model = keras.models.load_model("FullModelCheckpoint.keras")

    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


# Sampling the full train dataset to train on
full_train_dataset = (
    train_dataset.concatenate(pool_positives)
    .concatenate(pool_negatives)
    .cache()
    .shuffle(20000)
)

# Training the full model
full_dataset_model = train_full_model(full_train_dataset, val_dataset, test_dataset)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 150, 128)            │         384,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 150, 64)             │          41,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d                 │ (None, 64)                  │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 20)                  │           1,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 20)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 426,537 (1.63 MB)
#  Trainable params: 426,537 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - binary_accuracy: 0.6413 - false_negatives: 1737.1401 - false_positives: 5569.3501 - loss: 0.6506
# Epoch 1: val_loss improved from inf to 0.60718, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - binary_accuracy: 0.6414 - false_negatives: 1758.6519 - false_positives: 5592.0571 - loss: 0.6506 - val_binary_accuracy: 0.6846 - val_false_negatives: 1343.0000 - val_false_positives: 234.0000 - val_loss: 0.6072
# Epoch 2/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.7489 - false_negatives: 1837.2821 - false_positives: 3103.4358 - loss: 0.5420
# Epoch 2: val_loss improved from 0.60718 to 0.48230, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - binary_accuracy: 0.7491 - false_negatives: 1865.3291 - false_positives: 3133.4937 - loss: 0.5417 - val_binary_accuracy: 0.7636 - val_false_negatives: 167.0000 - val_false_positives: 1015.0000 - val_loss: 0.4823
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8105 - false_negatives: 1633.1592 - false_positives: 2210.8535 - loss: 0.4409
# Epoch 3: val_loss improved from 0.48230 to 0.39484, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - binary_accuracy: 0.8105 - false_negatives: 1645.1393 - false_positives: 2222.6772 - loss: 0.4409 - val_binary_accuracy: 0.8306 - val_false_negatives: 427.0000 - val_false_positives: 420.0000 - val_loss: 0.3948
# Epoch 4/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8386 - false_negatives: 1509.5065 - false_positives: 1788.2821 - loss: 0.3932
# Epoch 4: val_loss improved from 0.39484 to 0.36807, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - binary_accuracy: 0.8385 - false_negatives: 1532.4114 - false_positives: 1808.7468 - loss: 0.3934 - val_binary_accuracy: 0.8376 - val_false_negatives: 485.0000 - val_false_positives: 327.0000 - val_loss: 0.3681
# Epoch 5/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - binary_accuracy: 0.8559 - false_negatives: 1419.1154 - false_positives: 1560.1923 - loss: 0.3552
# Epoch 5: val_loss improved from 0.36807 to 0.34387, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - binary_accuracy: 0.8558 - false_negatives: 1439.9873 - false_positives: 1578.5443 - loss: 0.3554 - val_binary_accuracy: 0.8488 - val_false_negatives: 355.0000 - val_false_positives: 401.0000 - val_loss: 0.3439
# Epoch 6/20
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - binary_accuracy: 0.8602 - false_negatives: 1322.0581 - false_positives: 1514.5548 - loss: 0.3481
# Epoch 6: val_loss improved from 0.34387 to 0.34097, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - binary_accuracy: 0.8602 - false_negatives: 1350.8544 - false_positives: 1540.6519 - loss: 0.3482 - val_binary_accuracy: 0.8542 - val_false_negatives: 274.0000 - val_false_positives: 455.0000 - val_loss: 0.3410
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8717 - false_negatives: 1251.2421 - false_positives: 1397.1592 - loss: 0.3284
# Epoch 7: val_loss did not improve from 0.34097
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.8717 - false_negatives: 1260.0823 - false_positives: 1405.1962 - loss: 0.3284 - val_binary_accuracy: 0.8440 - val_false_negatives: 175.0000 - val_false_positives: 605.0000 - val_loss: 0.3610
# Epoch 8/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8776 - false_negatives: 1155.8472 - false_positives: 1329.4204 - loss: 0.3190
# Epoch 8: val_loss did not improve from 0.34097
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - binary_accuracy: 0.8776 - false_negatives: 1164.2025 - false_positives: 1336.8164 - loss: 0.3191 - val_binary_accuracy: 0.8548 - val_false_negatives: 221.0000 - val_false_positives: 505.0000 - val_loss: 0.3497
# Epoch 9/20
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8840 - false_negatives: 1170.7742 - false_positives: 1184.6129 - loss: 0.3026
# Epoch 9: val_loss did not improve from 0.34097
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - binary_accuracy: 0.8839 - false_negatives: 1197.4304 - false_positives: 1205.6393 - loss: 0.3028 - val_binary_accuracy: 0.8558 - val_false_negatives: 244.0000 - val_false_positives: 477.0000 - val_loss: 0.3474
# Epoch 10/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - binary_accuracy: 0.8895 - false_negatives: 1172.5769 - false_positives: 1100.6090 - loss: 0.2871
# Epoch 10: val_loss did not improve from 0.34097
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - binary_accuracy: 0.8895 - false_negatives: 1189.8987 - false_positives: 1113.5127 - loss: 0.2872 - val_binary_accuracy: 0.7776 - val_false_negatives: 1033.0000 - val_false_positives: 79.0000 - val_loss: 0.4581
# Epoch 10: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'binary_accuracy': 0.8478000164031982, 'false_negatives': 308.0, 'false_positives': 453.0, 'loss': 0.34953004121780396}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Training via Active Learning
#
# The general process we follow when performing Active Learning is demonstrated below:
#
# ![Active Learning](https://i.imgur.com/dmNKusp.png)
#
# The pipeline can be summarized in five parts:
#
# 1. Sample and annotate a small, balanced training dataset
# 2. Train the model on this small subset
# 3. Evaluate the model on a balanced testing set
# 4. If the model satisfies the business criteria, deploy it in a real time setting
# 5. If it doesn't pass the criteria, sample a few more samples according to the ratio of
# false positives and negatives, add them to the training set and repeat from step 2 till
# the model passes the tests or till all available data is exhausted.
#
# For the code below, we will perform sampling using the following formula:<br/>
#
# ![Ratio Sampling](https://i.imgur.com/LyZEiZL.png)
#
# Active Learning techniques use callbacks extensively for progress tracking. We will be
# using model checkpointing and early stopping for this example. The `patience` parameter
# for Early Stopping can help minimize overfitting and the time required. We have set it
# `patience=4` for now but since the model is robust, we can increase the patience level if
# desired.
#
# Note: We are not loading the checkpoint after the first training iteration. In my
# experience working on Active Learning techniques, this helps the model probe the
# newly formed loss landscape. Even if the model fails to improve in the second iteration,
# we will still gain insight about the possible future false positive and negative rates.
# This will help us sample a better set in the next iteration where the model will have a
# greater chance to improve.

# %%
def train_active_learning_models(
    train_dataset,
    pool_negatives,
    pool_positives,
    val_dataset,
    test_dataset,
    num_iterations=3,
    sampling_size=5000,
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.keras", save_best_only=True, verbose=1
    )
    # Here, patience is set to 4. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=4, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(20000).batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = ops.where(ops.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

        print("-" * 100)
        print(
            f"Number of zeros incorrectly classified: {false_negatives}, Number of ones incorrectly classified: {false_positives}"
        )

        # This technique of Active Learning demonstrates ratio based sampling where
        # Number of ones/zeros to sample = Number of ones/zeros incorrectly classified / Total incorrectly classified
        if false_negatives != 0 and false_positives != 0:
            total = false_negatives + false_positives
            sample_ratio_ones, sample_ratio_zeros = (
                false_positives / total,
                false_negatives / total,
            )
        # In the case where all samples are correctly predicted, we can sample both classes equally
        else:
            sample_ratio_ones, sample_ratio_zeros = 0.5, 0.5

        print(
            f"Sample ratio for positives: {sample_ratio_ones}, Sample ratio for negatives:{sample_ratio_zeros}"
        )

        # Sample the required number of ones and zeros
        sampled_dataset = pool_negatives.take(
            int(sample_ratio_zeros * sampling_size)
        ).concatenate(pool_positives.take(int(sample_ratio_ones * sampling_size)))

        # Skip the sampled data points to avoid repetition of sample
        pool_negatives = pool_negatives.skip(int(sample_ratio_zeros * sampling_size))
        pool_positives = pool_positives.skip(int(sample_ratio_ones * sampling_size))

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives(),
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(20000).batch(256),
            validation_data=val_dataset,
            epochs=20,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=4, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("AL_Model.keras")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model


active_learning_model = train_active_learning_models(
    train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset
)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 150, 128)            │         384,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 150, 64)             │          41,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d_1               │ (None, 64)                  │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 20)                  │           1,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 20)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 426,537 (1.63 MB)
#  Trainable params: 426,537 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)
# Starting to train with 15000 samples
# Epoch 1/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.5025 - false_negatives_1: 1198.9138 - false_positives_1: 2531.8621 - loss: 0.6930
# Epoch 1: val_loss improved from inf to 0.69126, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - binary_accuracy: 0.5029 - false_negatives_1: 1263.0167 - false_positives_1: 2586.5000 - loss: 0.6930 - val_binary_accuracy: 0.5134 - val_false_negatives_1: 19.0000 - val_false_positives_1: 2414.0000 - val_loss: 0.6913
# Epoch 2/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.5607 - false_negatives_1: 1638.6949 - false_positives_1: 1643.4576 - loss: 0.6891
# Epoch 2: val_loss improved from 0.69126 to 0.67532, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - binary_accuracy: 0.5610 - false_negatives_1: 1664.3667 - false_positives_1: 1667.5333 - loss: 0.6890 - val_binary_accuracy: 0.5890 - val_false_negatives_1: 1883.0000 - val_false_positives_1: 172.0000 - val_loss: 0.6753
# Epoch 3/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - binary_accuracy: 0.6216 - false_negatives_1: 1383.9153 - false_positives_1: 1490.2543 - loss: 0.6616
# Epoch 3: val_loss improved from 0.67532 to 0.58826, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - binary_accuracy: 0.6218 - false_negatives_1: 1403.8500 - false_positives_1: 1512.9500 - loss: 0.6614 - val_binary_accuracy: 0.7192 - val_false_negatives_1: 1104.0000 - val_false_positives_1: 300.0000 - val_loss: 0.5883
# Epoch 4/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.6911 - false_negatives_1: 1023.4745 - false_positives_1: 1331.0509 - loss: 0.6023
# Epoch 4: val_loss improved from 0.58826 to 0.54369, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - binary_accuracy: 0.6913 - false_negatives_1: 1038.2333 - false_positives_1: 1351.9166 - loss: 0.6021 - val_binary_accuracy: 0.7344 - val_false_negatives_1: 241.0000 - val_false_positives_1: 1087.0000 - val_loss: 0.5437
# Epoch 5/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.7299 - false_negatives_1: 912.7895 - false_positives_1: 1081.1228 - loss: 0.5589
# Epoch 5: val_loss improved from 0.54369 to 0.48901, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - binary_accuracy: 0.7303 - false_negatives_1: 957.5167 - false_positives_1: 1131.9833 - loss: 0.5581 - val_binary_accuracy: 0.7968 - val_false_negatives_1: 533.0000 - val_false_positives_1: 483.0000 - val_loss: 0.4890
# Epoch 6/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.7758 - false_negatives_1: 758.1404 - false_positives_1: 926.4386 - loss: 0.4959
# Epoch 6: val_loss improved from 0.48901 to 0.42060, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - binary_accuracy: 0.7759 - false_negatives_1: 794.7833 - false_positives_1: 971.9000 - loss: 0.4956 - val_binary_accuracy: 0.8146 - val_false_negatives_1: 352.0000 - val_false_positives_1: 575.0000 - val_loss: 0.4206
# Epoch 7/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8036 - false_negatives_1: 690.3965 - false_positives_1: 811.3448 - loss: 0.4410
# Epoch 7: val_loss improved from 0.42060 to 0.39814, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - binary_accuracy: 0.8035 - false_negatives_1: 713.4833 - false_positives_1: 838.2333 - loss: 0.4412 - val_binary_accuracy: 0.8286 - val_false_negatives_1: 485.0000 - val_false_positives_1: 372.0000 - val_loss: 0.3981
# Epoch 8/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - binary_accuracy: 0.8152 - false_negatives_1: 622.5593 - false_positives_1: 809.5593 - loss: 0.4303
# Epoch 8: val_loss did not improve from 0.39814
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - binary_accuracy: 0.8152 - false_negatives_1: 632.1166 - false_positives_1: 822.4333 - loss: 0.4303 - val_binary_accuracy: 0.8184 - val_false_negatives_1: 646.0000 - val_false_positives_1: 262.0000 - val_loss: 0.4145
# Epoch 9/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8272 - false_negatives_1: 582.6102 - false_positives_1: 743.4915 - loss: 0.4030
# Epoch 9: val_loss improved from 0.39814 to 0.37848, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - binary_accuracy: 0.8272 - false_negatives_1: 591.6000 - false_positives_1: 755.2000 - loss: 0.4030 - val_binary_accuracy: 0.8366 - val_false_negatives_1: 486.0000 - val_false_positives_1: 331.0000 - val_loss: 0.3785
# Epoch 10/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8506 - false_negatives_1: 524.7018 - false_positives_1: 617.5439 - loss: 0.3694
# Epoch 10: val_loss did not improve from 0.37848
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - binary_accuracy: 0.8503 - false_negatives_1: 552.6166 - false_positives_1: 649.4833 - loss: 0.3700 - val_binary_accuracy: 0.8296 - val_false_negatives_1: 255.0000 - val_false_positives_1: 597.0000 - val_loss: 0.3928
# Epoch 11/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8529 - false_negatives_1: 511.2982 - false_positives_1: 573.8246 - loss: 0.3568
# Epoch 11: val_loss improved from 0.37848 to 0.36555, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.8530 - false_negatives_1: 536.6166 - false_positives_1: 602.2667 - loss: 0.3567 - val_binary_accuracy: 0.8412 - val_false_negatives_1: 390.0000 - val_false_positives_1: 404.0000 - val_loss: 0.3656
# Epoch 12/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8555 - false_negatives_1: 508.9483 - false_positives_1: 600.3276 - loss: 0.3498
# Epoch 12: val_loss improved from 0.36555 to 0.36289, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - binary_accuracy: 0.8556 - false_negatives_1: 524.6833 - false_positives_1: 619.6500 - loss: 0.3497 - val_binary_accuracy: 0.8440 - val_false_negatives_1: 359.0000 - val_false_positives_1: 421.0000 - val_loss: 0.3629
# Epoch 13/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.8618 - false_negatives_1: 463.6441 - false_positives_1: 582.1525 - loss: 0.3405
# Epoch 13: val_loss did not improve from 0.36289
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - binary_accuracy: 0.8619 - false_negatives_1: 470.5833 - false_positives_1: 590.9333 - loss: 0.3403 - val_binary_accuracy: 0.7850 - val_false_negatives_1: 108.0000 - val_false_positives_1: 967.0000 - val_loss: 0.5231
# Epoch 14/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - binary_accuracy: 0.8663 - false_negatives_1: 428.7242 - false_positives_1: 549.9828 - loss: 0.3283
# Epoch 14: val_loss did not improve from 0.36289
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - binary_accuracy: 0.8665 - false_negatives_1: 443.1667 - false_positives_1: 567.3500 - loss: 0.3282 - val_binary_accuracy: 0.8232 - val_false_negatives_1: 652.0000 - val_false_positives_1: 232.0000 - val_loss: 0.3928
# Epoch 15/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8805 - false_negatives_1: 408.2456 - false_positives_1: 478.4912 - loss: 0.2995
# Epoch 15: val_loss improved from 0.36289 to 0.36118, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.8804 - false_negatives_1: 430.1833 - false_positives_1: 503.4000 - loss: 0.3000 - val_binary_accuracy: 0.8432 - val_false_negatives_1: 403.0000 - val_false_positives_1: 381.0000 - val_loss: 0.3612
# Epoch 16/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8927 - false_negatives_1: 392.3509 - false_positives_1: 417.7368 - loss: 0.2889
# Epoch 16: val_loss did not improve from 0.36118
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8926 - false_negatives_1: 411.8667 - false_positives_1: 438.9333 - loss: 0.2891 - val_binary_accuracy: 0.8296 - val_false_negatives_1: 217.0000 - val_false_positives_1: 635.0000 - val_loss: 0.4022
# Epoch 17/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8947 - false_negatives_1: 378.3621 - false_positives_1: 407.6379 - loss: 0.2845
# Epoch 17: val_loss did not improve from 0.36118
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - binary_accuracy: 0.8947 - false_negatives_1: 390.8500 - false_positives_1: 420.8167 - loss: 0.2843 - val_binary_accuracy: 0.7872 - val_false_negatives_1: 114.0000 - val_false_positives_1: 950.0000 - val_loss: 0.5681
# Epoch 18/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9024 - false_negatives_1: 338.0517 - false_positives_1: 387.2586 - loss: 0.2767
# Epoch 18: val_loss did not improve from 0.36118
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.9024 - false_negatives_1: 350.2500 - false_positives_1: 400.4167 - loss: 0.2765 - val_binary_accuracy: 0.8410 - val_false_negatives_1: 401.0000 - val_false_positives_1: 394.0000 - val_loss: 0.3742
# Epoch 19/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - binary_accuracy: 0.9074 - false_negatives_1: 338.6035 - false_positives_1: 362.4828 - loss: 0.2577
# Epoch 19: val_loss did not improve from 0.36118
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - binary_accuracy: 0.9073 - false_negatives_1: 350.0833 - false_positives_1: 374.4333 - loss: 0.2578 - val_binary_accuracy: 0.8408 - val_false_negatives_1: 384.0000 - val_false_positives_1: 412.0000 - val_loss: 0.3778
# Epoch 19: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 409.0, Number of ones incorrectly classified: 388.0
# Sample ratio for positives: 0.4868255959849435, Sample ratio for negatives:0.5131744040150564
# Starting training with 19999 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8807 - false_negatives_2: 555.3038 - false_positives_2: 623.8481 - loss: 0.3107
# Epoch 1: val_loss did not improve from 0.36118
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - binary_accuracy: 0.8807 - false_negatives_2: 561.7625 - false_positives_2: 631.0625 - loss: 0.3106 - val_binary_accuracy: 0.8448 - val_false_negatives_2: 377.0000 - val_false_positives_2: 399.0000 - val_loss: 0.3689
# Epoch 2/20
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.9029 - false_negatives_2: 477.7013 - false_positives_2: 514.3376 - loss: 0.2678
# Epoch 2: val_loss did not improve from 0.36118
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - binary_accuracy: 0.9028 - false_negatives_2: 496.7625 - false_positives_2: 533.5000 - loss: 0.2680 - val_binary_accuracy: 0.8204 - val_false_negatives_2: 695.0000 - val_false_positives_2: 203.0000 - val_loss: 0.4247
# Epoch 3/20
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.9113 - false_negatives_2: 441.7532 - false_positives_2: 455.7792 - loss: 0.2494
# Epoch 3: val_loss did not improve from 0.36118
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.9112 - false_negatives_2: 458.9000 - false_positives_2: 474.5125 - loss: 0.2497 - val_binary_accuracy: 0.8246 - val_false_negatives_2: 668.0000 - val_false_positives_2: 209.0000 - val_loss: 0.4170
# Epoch 4/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.9170 - false_negatives_2: 412.8607 - false_positives_2: 432.5443 - loss: 0.2464
# Epoch 4: val_loss did not improve from 0.36118
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.9170 - false_negatives_2: 418.0500 - false_positives_2: 437.7375 - loss: 0.2464 - val_binary_accuracy: 0.8400 - val_false_negatives_2: 389.0000 - val_false_positives_2: 411.0000 - val_loss: 0.3955
# Epoch 5/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - binary_accuracy: 0.9184 - false_negatives_2: 403.9873 - false_positives_2: 445.5443 - loss: 0.2352
# Epoch 5: val_loss did not improve from 0.36118
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - binary_accuracy: 0.9183 - false_negatives_2: 408.8375 - false_positives_2: 450.9375 - loss: 0.2352 - val_binary_accuracy: 0.8280 - val_false_negatives_2: 618.0000 - val_false_positives_2: 242.0000 - val_loss: 0.4372
# Epoch 5: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 427.0, Number of ones incorrectly classified: 361.0
# Sample ratio for positives: 0.4581218274111675, Sample ratio for negatives:0.5418781725888325
# Starting training with 24998 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - binary_accuracy: 0.8546 - false_negatives_3: 904.4020 - false_positives_3: 872.4020 - loss: 0.3611
# Epoch 1: val_loss improved from 0.36118 to 0.35818, saving model to AL_Model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - binary_accuracy: 0.8547 - false_negatives_3: 920.6768 - false_positives_3: 890.0101 - loss: 0.3608 - val_binary_accuracy: 0.8426 - val_false_negatives_3: 269.0000 - val_false_positives_3: 518.0000 - val_loss: 0.3582
# Epoch 2/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.8800 - false_negatives_3: 721.4846 - false_positives_3: 806.5258 - loss: 0.3126
# Epoch 2: val_loss improved from 0.35818 to 0.34966, saving model to AL_Model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - binary_accuracy: 0.8799 - false_negatives_3: 736.4041 - false_positives_3: 822.5353 - loss: 0.3127 - val_binary_accuracy: 0.8498 - val_false_negatives_3: 312.0000 - val_false_positives_3: 439.0000 - val_loss: 0.3497
# Epoch 3/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.8861 - false_negatives_3: 685.2783 - false_positives_3: 757.4846 - loss: 0.2988
# Epoch 3: val_loss did not improve from 0.34966
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - binary_accuracy: 0.8860 - false_negatives_3: 699.8182 - false_positives_3: 772.7475 - loss: 0.2990 - val_binary_accuracy: 0.8448 - val_false_negatives_3: 249.0000 - val_false_positives_3: 527.0000 - val_loss: 0.3544
# Epoch 4/20
# 96/98 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8896 - false_negatives_3: 660.0312 - false_positives_3: 704.4062 - loss: 0.2885
# Epoch 4: val_loss did not improve from 0.34966
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - binary_accuracy: 0.8896 - false_negatives_3: 680.7980 - false_positives_3: 726.0202 - loss: 0.2885 - val_binary_accuracy: 0.8500 - val_false_negatives_3: 377.0000 - val_false_positives_3: 373.0000 - val_loss: 0.3505
# Epoch 5/20
# 96/98 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8987 - false_negatives_3: 643.1771 - false_positives_3: 649.4271 - loss: 0.2739
# Epoch 5: val_loss did not improve from 0.34966
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - binary_accuracy: 0.8985 - false_negatives_3: 663.6869 - false_positives_3: 670.0909 - loss: 0.2741 - val_binary_accuracy: 0.8466 - val_false_negatives_3: 458.0000 - val_false_positives_3: 309.0000 - val_loss: 0.3554
# Epoch 6/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.9091 - false_negatives_3: 560.6224 - false_positives_3: 615.9081 - loss: 0.2502
# Epoch 6: val_loss did not improve from 0.34966
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - binary_accuracy: 0.9090 - false_negatives_3: 566.4343 - false_positives_3: 622.1313 - loss: 0.2503 - val_binary_accuracy: 0.8402 - val_false_negatives_3: 552.0000 - val_false_positives_3: 247.0000 - val_loss: 0.3921
# Epoch 6: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 333.0, Number of ones incorrectly classified: 438.0
# Sample ratio for positives: 0.5680933852140078, Sample ratio for negatives:0.43190661478599224
# Starting training with 29997 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - binary_accuracy: 0.8639 - false_negatives_4: 944.8879 - false_positives_4: 1036.7500 - loss: 0.3469
# Epoch 1: val_loss improved from 0.34966 to 0.34444, saving model to AL_Model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 12s 52ms/step - binary_accuracy: 0.8640 - false_negatives_4: 968.7311 - false_positives_4: 1061.7479 - loss: 0.3465 - val_binary_accuracy: 0.8550 - val_false_negatives_4: 270.0000 - val_false_positives_4: 455.0000 - val_loss: 0.3444
# Epoch 2/20
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - binary_accuracy: 0.8883 - false_negatives_4: 820.0690 - false_positives_4: 893.0172 - loss: 0.2934
# Epoch 2: val_loss improved from 0.34444 to 0.34061, saving model to AL_Model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - binary_accuracy: 0.8882 - false_negatives_4: 841.6218 - false_positives_4: 916.5294 - loss: 0.2936 - val_binary_accuracy: 0.8538 - val_false_negatives_4: 380.0000 - val_false_positives_4: 351.0000 - val_loss: 0.3406
# Epoch 3/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.8943 - false_negatives_4: 805.7692 - false_positives_4: 830.1539 - loss: 0.2866
# Epoch 3: val_loss did not improve from 0.34061
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - binary_accuracy: 0.8942 - false_negatives_4: 819.7563 - false_positives_4: 844.6722 - loss: 0.2867 - val_binary_accuracy: 0.8374 - val_false_negatives_4: 587.0000 - val_false_positives_4: 226.0000 - val_loss: 0.3632
# Epoch 4/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.9000 - false_negatives_4: 747.8547 - false_positives_4: 784.9316 - loss: 0.2659
# Epoch 4: val_loss did not improve from 0.34061
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - binary_accuracy: 0.8999 - false_negatives_4: 761.1345 - false_positives_4: 798.8151 - loss: 0.2660 - val_binary_accuracy: 0.8430 - val_false_negatives_4: 536.0000 - val_false_positives_4: 249.0000 - val_loss: 0.3551
# Epoch 5/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - binary_accuracy: 0.9046 - false_negatives_4: 728.6695 - false_positives_4: 764.0085 - loss: 0.2600
# Epoch 5: val_loss did not improve from 0.34061
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - binary_accuracy: 0.9045 - false_negatives_4: 734.7227 - false_positives_4: 770.5042 - loss: 0.2600 - val_binary_accuracy: 0.8404 - val_false_negatives_4: 560.0000 - val_false_positives_4: 238.0000 - val_loss: 0.3724
# Epoch 6/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9090 - false_negatives_4: 688.5385 - false_positives_4: 710.7265 - loss: 0.2443
# Epoch 6: val_loss did not improve from 0.34061
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - binary_accuracy: 0.9089 - false_negatives_4: 700.4117 - false_positives_4: 723.1849 - loss: 0.2445 - val_binary_accuracy: 0.8514 - val_false_negatives_4: 271.0000 - val_false_positives_4: 472.0000 - val_loss: 0.3775
# Epoch 6: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'binary_accuracy': 0.850600004196167, 'false_negatives_4': 392.0, 'false_positives_4': 355.0, 'loss': 0.34771081805229187}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Conclusion
#
# Active Learning is a growing area of research. This example demonstrates the cost-efficiency
# benefits of using Active Learning, as it eliminates the need to annotate large amounts of
# data, saving resources.
#
# The following are some noteworthy observations from this example:
#
# 1. We only require 30,000 samples to reach the same (if not better) scores as the model
# trained on the full dataset. This means that in a real life setting, we save the effort
# required for annotating 10,000 images!
# 2. The number of false negatives and false positives are well balanced at the end of the
# training as compared to the skewed ratio obtained from the full training. This makes the
# model slightly more useful in real life scenarios where both the labels hold equal
# importance.
#
# For further reading about the types of sampling ratios, training techniques or available
# open source libraries/implementations, you can refer to the resources below:
#
# 1. [Active Learning Literature Survey](http://burrsettles.com/pub/settles.activelearning.pdf) (Burr Settles, 2010).
# 2. [modAL](https://github.com/modAL-python/modAL): A Modular Active Learning framework.
# 3. Google's unofficial [Active Learning playground](https://github.com/google/active-learning).
